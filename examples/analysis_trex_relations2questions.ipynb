# %%
import datasets
import requests
from datasets import load_dataset 
import numpy as np
import openai
from tqdm import tqdm

# %%
api_key = open("/data/katie_kang/openai_key_file.txt", "r").read()
openai.api_key = api_key.strip()

# %%
def get_wikidata_property_label(property_id):
    url = "https://www.wikidata.org/w/api.php"
    params = {
        "action": "wbgetentities",
        "ids": property_id,
        "props": "labels",
        "languages": "en",
        "format": "json",
    }
    response = requests.get(url, params=params)
    data = response.json()
    label = data['entities'][property_id]['labels']['en']['value']
    return label

# %%
dataset2 = load_dataset('relbert/t_rex')

# %%
trex_train_relations = list(set(dataset2["train"]['relation']))

# %%
base_prompt = """Write a question using the provided relation, such that the question includes the head and the relation, and the question is the tail. Write the question such that the head is replaced with '[X]'. Answer with only the question.

Examples
Relation: [Bank] is the central bank of [Country]
Question: What country is [X] the central bank of?

Relation: [Country] is in [Continent]
Question: What sports team is [X] is member of?


FILL IN NOT TOTALLY DONE
"""

# def get_prompt(relation, head, tail):
#     prompt = base_prompt
#     prompt = prompt.replace("[relation]", relation)
#     prompt = prompt.replace("[head]", head)
#     prompt = prompt.replace("[tail]", tail)
#     return prompt

# %%
base_prompt = """Write a question using the provided head, tail, and relation, such that the question includes the head and the relation, and the question is the tail. Write the question such that the head is replaced with '[X]'. Do NOT include information from the head or tail in the question. Answer with only the question.

Examples
Relation: developer
Head: Neverwinter Nights 2
Tail: Obsidian Entertainment
Question: Who is the developer of [X]?

Relation: member of sports team
Head: Roger Nilsen
Tail: Molde
Question: What sports team is [X] is member of?

Relation: part of
Head: Tungusic
Tail: Altaic family
Question: What is [X] part of?

Relation: surface played on
Head: Jakarta Open
Tail: outdoor hard courts
Question: What kind of surface is [X] played on?

Query
Relation: [relation]
Head: [head]
Tail: [tail]
Question: """

def get_prompt(relation, head, tail):
    prompt = base_prompt
    prompt = prompt.replace("[relation]", relation)
    prompt = prompt.replace("[head]", head)
    prompt = prompt.replace("[tail]", tail)
    return prompt

# %%
relations_train_dict = {}
for i in tqdm(range(len(trex_train_relations))):
    trex_train_relation = trex_train_relations[i]
    if trex_train_relation.startswith("P"):
        try:
            relation = (get_wikidata_property_label(trex_train_relation))
            relation_idxs = np.where(np.array(dataset2["train"]['relation']) == trex_train_relation)[0]
            prompt1 = get_prompt(relation, dataset2["train"][int(relation_idxs[0])]['head'], dataset2["train"][int(relation_idxs[0])]['tail'])
            response1 = openai.ChatCompletion.create(model="gpt-4",
                                                messages=[{"role": "user", "content": prompt1}] ,)
            # question1 = response1["choices"][0]["text"].lstrip().rstrip()
            question1 = response1["choices"][0]["message"]["content"].lstrip().rstrip()
            relations_train_dict[relation] = question1
        except:
            print("Error: ", trex_train_relation)
            continue
# Out:
#  11%|█         | 82/759 [02:12<11:55,  1.06s/it]
# Error:  P2439
#  20%|█▉        | 149/759 [04:00<14:02,  1.38s/it]
# Error:  P134
#  37%|███▋      | 278/759 [07:18<11:58,  1.49s/it]
# Error:  P2157
#  71%|███████   | 538/759 [14:27<04:23,  1.19s/it]
# Error:  P1962
#  97%|█████████▋| 736/759 [19:25<00:18,  1.21it/s]
# Error:  P796
# 100%|██████████| 759/759 [20:08<00:00,  1.59s/it]

# %%
relations_train_dict
# Out:
# {'surface played on': 'What kind of surface is [X] played on?',
#  'honorific suffix': 'What is the honorific suffix of [X]?',
#  'after a work by': 'Who is the original author of the work that [X] is based on?',
#  'physically interacts with': 'What does [X] physically interact with?',
#  'designed by': 'Who was [X] designed by?',
#  'inception': 'When was the inception of [X]?',
#  'capital of': 'What is the capital of [X]?',
#  'record held': 'What record does [X] hold?',
#  'team captain': 'Who is the team captain of [X]?',
#  'main subject': 'What is the main subject of [X]?',
#  'defendant': 'Who was the defendant in the [X]?',
#  'voice actor': 'Who is the voice actor in [X]?',
#  'torch lit by': 'Who was the torch lit by in [X]?',
#  'antiparticle': 'What is the antiparticle of [X]?',
#  'protocol': 'What protocol does the [X] use?',
#  'Roman praenomen': 'What is the Roman praenomen of [X]?',
#  'applies to jurisdiction': 'What jurisdiction does [X] apply to?',
#  'astronaut mission': 'What was the astronaut mission of [X]?',
#  'speaker': 'Who was the speaker of the [X]?',
#  'highest judicial authority': 'What is the highest judicial authority in [X]?',
#  'production statistics': 'What is the main product in the production statistics of [X]?',
#  'backup or reserve team or crew': 'Who was a member of the backup or reserve team or crew for [X]?',
#  'natural product of taxon': 'What is the natural taxon product of [X]?',
#  'has pet': 'Who is the pet of [X]?',
#  'foundational text': 'What is the foundational text of [X]?',
#  'vaccine for': 'What is the [X] vaccine for?',
#  'type of electrification': 'What type of electrification does [X] use?',
#  'academic degree': 'What is the academic degree of [X]?',
#  'date of disappearance': 'When did [X] disappear?',
#  'powered by': 'What is [X] powered by?',
#  'winner': 'Who was the winner of [X]?',
#  'developer': 'Who is the developer of [X]?',
#  'month of the year': 'What is the month of the year for [X]?',
#  'launch contractor': 'Who is the launch contractor for [X]?',
#  'edibility': 'Is [X] an edible mushroom?',
#  'office held by head of state': 'What office is held by the head of state in [X]?',
#  'site of astronomical discovery': 'Where was [X] discovered astronomically?',
#  'allegiance': 'What is the allegiance of [X]?',
#  'carries': 'What does the [X] carry?',
#  'office contested': 'What office is contested in the [X]?',
#  'manufacturer': 'Who is the manufacturer of [X]?',
#  'UNESCO language status': 'What is the UNESCO language status of [X]?',
#  'introduced feature': 'What feature was introduced in [X]?',
#  'godparent': 'Who is the godparent of [X]?',
#  'has facility': 'What type of facility does [X] have?',
#  'charted in': 'In which country did [X] chart?',
#  'occupation': 'What is the occupation of [X]?',
#  'platform': 'What platform does [X] run on?',
#  'location of creation': 'Where was [X] created?',
#  'programmer': 'Who is the programmer of [X]?',
#  'part of the series': 'What series is [X] a part of?',
#  'time period': 'What time period is associated with [X]?',
#  'Gram staining': 'What is the result of Gram staining for [X]?',
#  'taxon rank': 'What is the taxon rank of [X]?',
#  'cuisine': 'What type of cuisine is [X] a part of?',
#  'CPU': 'What is the CPU of [X]?',
#  'connects with': 'Where does [X] connect with?',
#  'instrumentation': 'What is one instrument used in the instrumentation of [X]?',
#  'consecrator': 'Who was the consecrator of [X]?',
#  'service retirement': 'When did [X] retire from service?',
#  'possible treatment': 'What is a possible treatment for [X]?',
#  'art director': 'Who is the art director of [X]?',
#  'has spin-off': 'What is a spin-off of [X]?',
#  'military rank': 'What is the military rank of [X]?',
#  'airline alliance': 'What airline alliance is [X] a part of?',
#  'cell component': 'What is the cell component of [X]?',
#  'separated from': 'What did [X] separate from?',
#  'interleaves with': 'What does [X] interleave with?',
#  'work period (start)': 'When did the work period of [X] start?',
#  'substitute/deputy/replacement of office/officeholder': 'Who is the substitute/deputy/replacement officeholder of the [X]?',
#  'sponsor': 'Who is the sponsor of [X]?',
#  'public holiday': 'What is a public holiday in [X]?',
#  'flag': 'What is the flag of [X]?',
#  'authority': 'Who is the authority of [X]?',
#  'diaspora': 'Who is the diaspora of [X]?',
#  'produced by': 'What is [X] produced by?',
#  'nominated for': 'What was [X] nominated for?',
#  'feast day': 'What is the feast day associated with [X]?',
#  'vessel': 'Which vessel was [X] transported by?',
#  'service entry': 'When did the service entry of [X] occur?',
#  'dedicated to': 'Who is [X] dedicated to?',
#  'native language': 'What is the native language of [X]?',
#  'main regulatory text': 'What is the main regulatory text of [X]?',
#  'affiliation': 'What is the affiliation of [X]?',
#  'GUI toolkit or framework': 'What GUI toolkit or framework does [X] use?',
#  'symptoms and signs': 'What symptoms and signs does [X] show on muscles?',
#  'archives at': 'Where are the archives of [X] located?',
#  'genre': 'What genre does [X] belong to?',
#  'sexual orientation': 'What is the sexual orientation of [X]?',
#  'mouth of the watercourse': 'What is the mouth of the watercourse of [X]?',
#  'owned by': 'Who owns [X]?',
#  'librettist': 'Who is the librettist of [X]?',
#  'contains settlement': 'What settlement does [X] contain?',
#  'distribution format': 'What is the distribution format for [X]?',
#  'place of publication': 'Where is [X] published?',
#  'applies to part': 'What does [X] apply to parts of?',
#  'arterial supply': 'What arterial supply does [X] receive blood from?',
#  'item operated': 'What item does [X] operate?',
#  'chivalric order': 'What chivalric order is [X] associated with?',
#  'structure replaced by': 'What structure did [X] get replaced by?',
#  'distributed by': 'Who distributed [X]?',
#  'ancestral home': 'Where is the ancestral home of [X]?',
#  'ethnic group': 'What ethnic group does [X] belong to?',
#  'terminus location': 'Where is the terminus location of [X]?',
#  'broadcast by': 'Which channel broadcasts [X]?',
#  'candidate': 'Who was a candidate in the [X]?',
#  'coextensive with': 'What is [X] coextensive with?',
#  'uses': 'What does [X] use?',
#  'central bank/issuer': 'Who is the central bank/issuer of [X]?',
#  'end time': 'When did [X] end?',
#  'patron saint': 'Who is the patron saint of [X]?',
#  'track gauge': 'What is the track gauge of [X]?',
#  'student of': 'Who was [X] a student of?',
#  'production designer': 'Who is the production designer for [X]?',
#  'commissioned by': 'Who commissioned [X]?',
#  'sport': 'What kind of sport does [X] play?',
#  'translator': 'Who is the translator of [X]?',
#  'species kept': 'What species are kept at [X]?',
#  'domain of saint or deity': 'What is the domain of the saint or deity [X]?',
#  'discoverer or inventor': 'Who is the discoverer or inventor of [X]?',
#  'copyright license': 'What is the copyright license for [X]?',
#  'place of detention': 'Where was [X] detained?',
#  'asteroid family': 'What is the asteroid family of [X]?',
#  'shipping port': 'What is the shipping port of [X]?',
#  'child': 'Who is a child of [X]?',
#  'located on street': 'What street is [X] located on?',
#  'choreographer': 'Who was the choreographer for [X]?',
#  'space launch vehicle': 'What is the space launch vehicle for [X]?',
#  'diplomatic relation': 'Who does [X] have a diplomatic relation with?',
#  'airline hub': 'What is the airline hub of [X]?',
#  'location': 'Where is [X] located?',
#  'legal form': 'What is the legal form of [X]?',
#  'has edition or translation': 'What is an edition or translation of [X]?',
#  'instruction set': 'What instruction set does [X] use?',
#  'residence': 'Where does [X] reside?',
#  'located in/on physical feature': 'Where is [X] physically located?',
#  'found in taxon': 'In which taxon is [X] found?',
#  'pendant of': 'What is [X] a pendant of?',
#  'has subsidiary': 'What is a subsidiary of [X]?',
#  'qualifies for event': 'What event does [X] qualify for?',
#  'sports discipline competed in': 'What sports discipline does [X] compete in?',
#  'via': 'What city does [X] pass through?',
#  'architectural style': 'What is the architectural style of [X]?',
#  'has facet polytope': 'What is the facet polytope of [X]?',
#  'wheel arrangement': 'What is the wheel arrangement of [X]?',
#  'does not have part': 'What is the element that [X] does not have as part of it?',
#  'edition or translation of': 'What is [X] an edition or translation of?',
#  'enclave within': 'What is [X] an enclave within?',
#  'geography of topic': 'What is the geography of the topic [X]?',
#  'has contributing factor': 'What was a contributing factor to [X]?',
#  'endemic to': 'Where is [X] endemic to?',
#  'contributor to the creative work or subject': 'Who is a contributor to the creative work or subject of [X]?',
#  'terminus': 'Where is the terminus of [X]?',
#  'highest point': 'What is the highest point in [X]?',
#  'located in protected area': 'Which protected area is [X] located in?',
#  'country for sport': 'Which country does [X] play sports for?',
#  'head coach': 'Who is the head coach of [X]?',
#  'game artist': 'Who is the game artist for [X]?',
#  'has effect': 'What effect does [X] have on the Last Judgment?',
#  'target': 'What is the target of [X]?',
#  'from narrative universe': 'Which narrative universe is [X] from?',
#  'foods traditionally associated': 'What is a food traditionally associated with [X]?',
#  'readable file format': 'What is a readable file format for [X]?',
#  'discovery method': 'What method was used to discover [X]?',
#  'date of baptism in early childhood': 'When was [X] baptised in early childhood?',
#  'language used': 'What language is used in [X]?',
#  'writable file format': 'What is a writable file format for [X]?',
#  'package management system': 'What is the package management system of [X]?',
#  'has natural reservoir': 'What is the natural reservoir of [X]?',
#  'next crossing downstream': 'What is the next crossing downstream from [X]?',
#  'penalty': 'What penalty did [X] receive?',
#  'investigated by': 'Who investigated [X]?',
#  'fictional or mythical analog of': 'Who is the fictional or mythical analog of [X]?',
#  'basin country': 'Which country is the basin of [X]?',
#  'parent peak': 'What is the parent peak of [X]?',
#  'habitat': 'Where is the habitat of [X]?',
#  'opposite of': 'What is the opposite of [X]?',
#  'located in the administrative territorial entity': 'In which administrative territorial entity is [X] located?',
#  'performer': 'Who is the performer in [X]?',
#  'educated at': 'Where was [X] educated at?',
#  'is a list of': 'What is [X] a list of?',
#  'league level above': 'What is the league level above [X]?',
#  'charge': 'What was the charge in the [X]?',
#  'time of object orbit decay': 'When did the object orbit decay of [X] occur?',
#  'drug or therapy used for treatment': 'What is a drug or therapy used for the treatment of [X]?',
#  'solid solution series with': 'What does [X] have a solid solution series with?',
#  'conflict': 'What conflict was [X] involved in?',
#  'published in': 'In what publication was [X] published in?',
#  'color': 'What color is [X]?',
#  'officially opened by': 'Who officially opened the [X]?',
#  'characters': 'Who is one of the characters in [X]?',
#  'house publication': 'What is the house publication of [X]?',
#  'port of registry': 'What is the port of registry for [X]?',
#  'indigenous to': 'Where is [X] indigenous to?',
#  'official symbol': 'What is the official symbol of [X]?',
#  'follows': 'What does [X] follow in the geological time scale?',
#  'central bank': 'What is the central bank of [X]?',
#  'history of topic': 'What is the history of the topic [X]?',
#  'notable work': 'What is a notable work of [X]?',
#  'office held by head of government': 'What office is held by the head of government in [X]?',
#  'approved by': 'Who approved the [X]?',
#  'IUCN conservation status': 'What is the IUCN conservation status of [X]?',
#  'family name': 'What is the family name of [X]?',
#  'crew member(s)': 'Who is a crew member of [X]?',
#  'significant event': 'What significant event is associated with [X]?',
#  'coat of arms': 'Who had [X] as their coat of arms?',
#  'investor': 'Who is an investor in [X]?',
#  'unmarried partner': 'Who is the unmarried partner of [X]?',
#  'creator': 'Who is the creator of [X]?',
#  'has goal': 'What is the goal of [X]?',
#  'depicts': 'Who does [X] depict?',
#  'voice type': 'What is the voice type of [X]?',
#  'student': 'Who was a student of [X]?',
#  'position played on team / speciality': 'What position does [X] play on the team?',
#  'organization directed by the office or position': 'What organization is directed by the office or position of [X]?',
#  'depends on software': 'What software does [X] depend on?',
#  'operator': 'Who is the operator of [X]?',
#  'place of burial': 'Where is [X] buried?',
#  'location of discovery': 'Where was [X] discovered?',
#  'fictional universe described in': 'In what fictional universe is the [X] described?',
#  'record label': 'What is the record label of [X]?',
#  'league level below': 'What league is directly below [X] in level?',
#  'location of landing': 'Where did [X] land?',
#  'carries scientific instrument': 'What scientific instrument does [X] carry?',
#  'tracklist': 'Is "[X]" part of the tracklist for which song?',
#  'currency': 'What is the currency used in [X]?',
#  'collection': 'Which collection does [X] belong to?',
#  'industry': 'What industry does [X] belong to?',
#  'chromosome': 'What chromosome is [X] located on?',
#  'country of origin': 'What is the country of origin of [X]?',
#  'parent taxon': 'What is the parent taxon of [X]?',
#  'social classification': 'What is the social classification of [X]?',
#  'work location': 'Where does [X] work?',
#  'official language': 'What is the official language of [X]?',
#  'damaged': 'What was damaged in the [X]?',
#  'religious order': 'What religious order is [X] part of?',
#  'asteroid spectral type': 'What is the asteroid spectral type of [X]?',
#  'taxon synonym': 'What is the taxon synonym of [X]?',
#  'cathedral': 'Where is the cathedral that [X] is associated with?',
#  'capital': 'Who consider [X] as their capital?',
#  'place of origin (Switzerland)': 'What is the place of origin in Switzerland for [X]?',
#  'game mode': 'What is the game mode of [X]?',
#  'religion or worldview': 'What is the religion or worldview of [X]?',
#  'political ideology': 'What is the political ideology of [X]?',
#  'architect': 'Who is the architect of [X]?',
#  'subject has role': 'What role does the [X] have in the military?',
#  'ammunition': 'What type of ammunition does [X] use?',
#  'temporal range end': 'When does the temporal range of [X] end?',
#  'influenced by': 'Who was [X] influenced by?',
#  'participating team': 'Which team participated in the [X]?',
#  'designated as terrorist by': 'Who has [X] been designated as terrorists by?',
#  'relative': 'Who is a relative of [X]?',
#  'contains the administrative territorial entity': 'What administrative territorial entity does [X] contain?',
#  'award received': 'What award did [X] receive?',
#  'canonization status': 'What is the canonization status of [X]?',
#  'brand': 'What is the brand of [X]?',
#  'medical condition treated': 'What medical condition is [X] treated with?',
#  'narrator': 'Who is the narrator of [X]?',
#  'operating system': 'What is the operating system of [X]?',
#  'child astronomical body': 'What is the child astronomical body of [X]?',
#  'spouse': 'Who is the spouse of [X]?',
#  'partner in business or sport': "Who is [X]'s partner in business or sport?",
#  'league': 'What league does [X] play in?',
#  'cast member': 'Who is a cast member in [X]?',
#  'followed by': 'Who followed [X] in succession?',
#  'coordinate location': 'What is the coordinate location of [X]?',
#  'list of characters': 'Is Donald Duck a character in [X]?',
#  'has tense': 'What tense does [X] have?',
#  'measures': 'What does [X] measure?',
#  'Fach vocal classification': 'What is the Fach vocal classification of [X]?',
#  'corporate officer': 'Who is the corporate officer of [X]?',
#  'mushroom ecological type': 'What is the mushroom ecological type of [X]?',
#  'organizer': 'Who is the organizer of [X]?',
#  'continent': 'Which continent is [X] located in?',
#  'title of chess person': 'What is the title of the chess person [X]?',
#  'permanent duplicated item': 'What is a permanent duplicated item of [X]?',
#  'instrument': 'What instrument does [X] play?',
#  'sibling': 'Who is a sibling of [X]?',
#  'costume designer': 'Who is the costume designer for [X]?',
#  'place served by transport hub': 'What place is served by the transport hub [X]?',
#  'represents': 'Who does [X] represent?',
#  'heritage designation': 'What is the heritage designation of [X]?',
#  'incarnation of': 'Who is [X] an incarnation of?',
#  'position held': 'What position did [X] hold?',
#  'location of formation': 'Where was [X] formed?',
#  'has cause': 'What is the cause of [X]?',
#  'said to be the same as': 'Who is [X] said to be the same as?',
#  'issued by': 'Who issued the position of [X]?',
#  'operating area': 'What is the operating area of [X]?',
#  'has part(s)': 'What country is a part of [X]?',
#  'part of': 'What event was [X] part of?',
#  'drafted by': 'Who was [X] drafted by?',
#  'headquarters location': 'Where is the headquarters location of [X]?',
#  'used metre': 'What type of metre is used in [X]?',
#  'binding of software library': 'What software library is [X] a binding of?',
#  'software engine': 'What is the software engine used by [X]?',
#  'legislative body': 'What is the legislative body of [X]?',
#  'different from': 'How is [X] different from DRC?',
#  'academic major': 'What is the academic major of [X]?',
#  'original broadcaster': 'Who is the original broadcaster of [X]?',
#  'has use': 'What is the use of [X]?',
#  'convicted of': 'What was [X] convicted of?',
#  'illustrator': 'Who is the illustrator of [X]?',
#  'adjacent station': 'What is the adjacent station to [X]?',
#  'stock exchange': 'On which stock exchange is [X] listed?',
#  'offers view on': 'What does [X] offer a view on?',
#  'professorship': 'What is the profession of [X]?',
#  'mascot': 'Who is the mascot of [X]?',
#  'musical conductor': 'Who is the musical conductor of [X]?',
#  'mount': 'What is the name of the mount of [X]?',
#  'cover art by': 'Who is the cover art by for [X]?',
#  'head of state': 'Who is the head of state of [X]?',
#  'donated by': 'Who donated [X]?',
#  'lake outflow': 'What is the outflow river of [X]?',
#  'cause of destruction': 'What was the cause of destruction for [X]?',
#  'has grammatical mood': 'What grammatical mood does [X] have?',
#  'valid in period': 'During which period was the title [X] valid for the Persians?',
#  'temporal range start': 'When does the temporal range start for [X]?',
#  'route of administration': 'What is the route of administration for [X]?',
#  'engine configuration': 'What is the engine configuration of [X]?',
#  'sex or gender': 'What is the sex or gender identity of [X]?',
#  'party chief representative': 'Who is the party chief representative of [X]?',
#  'business division': 'What is a business division of [X]?',
#  'is the study of': 'What is the study of [X]?',
#  'connecting line': 'What is the connecting line for [X]?',
#  'sports season of league or competition': 'What league or competition is the [X] a sports season of?',
#  'partially coincident with': 'What does [X] partially coincide with?',
#  'place of death': 'Where did [X] die?',
#  'facet of': 'What is [X] a facet of?',
#  'has part(s) of the class': 'What is a part of the class of [X]?',
#  'movement': 'What movement is [X] associated with?',
#  'type of variable star': 'What type of variable star is [X]?',
#  'encodes': 'What does the gene [X] encode?',
#  'composer': 'Who is the composer of [X]?',
#  'designed to carry': 'Who is [X] designed to carry?',
#  'constellation': 'What constellation is [X] located in?',
#  'chairperson': 'Who is the chairperson of [X]?',
#  'territory overlaps': 'What territory does [X] overlap with?',
#  'has characteristic': 'What is a characteristic of [X]?',
#  'field of work': 'What is the field of work of [X]?',
#  'recorded at studio or venue': 'Where was [X] recorded?',
#  'depicted by': 'Who is [X] depicted by?',
#  'input device': 'What is the input device used for [X]?',
#  'main building contractor': 'Who was the main building contractor for [X]?',
#  'date of death': 'When was the date of death of [X]?',
#  'date of first performance': 'When was the first performance of [X]?',
#  'executive body': 'What is the executive body of [X]?',
#  'represented by': 'What team does [X] represented by?',
#  'occupant': 'Who is the occupant of [X]?',
#  'contributing factor of': 'How is [X] a contributing factor of?',
#  'minor planet group': 'What minor planet group does [X] belong to?',
#  'afflicts': 'What does [X] afflict?',
#  'biological process': 'What biological process is [X] involved in?',
#  'languages spoken, written or signed': 'What language is [X] able to speak, write or sign?',
#  'of': 'What field of study is [X] a concept of?',
#  'replaced by': 'Who did [X] get replaced by?',
#  'wing configuration': 'What is the wing configuration of [X]?',
#  'director / manager': 'Who was the director or manager of [X]?',
#  'twinned administrative body': 'What is the twinned administrative body of [X]?',
#  'shape': 'What is the shape of [X]?',
#  'next crossing upstream': 'What is the next crossing upstream from [X]?',
#  'vessel class': 'What is the vessel class of [X]?',
#  'competition class': 'What is the competition class of [X]?',
#  'writing system': 'What writing system does [X] use?',
#  'solved by': 'Who solved [X]?',
#  'inflows': 'What is the source of inflows for [X]?',
#  'start time': 'When did [X] start?',
#  'overlies': 'What does [X] overlie?',
#  'mother house': 'What is the mother house of [X]?',
#  'culture': 'What culture is [X] part of?',
#  'interaction': 'What type of interaction does [X] have?',
#  'dissolved, abolished or demolished date': 'When was [X] dissolved, abolished or demolished?',
#  'medical condition': 'What medical condition did [X] have?',
#  'director': 'Who is the director of [X]?',
#  'killed by': 'What was [X] killed by?',
#  'lyrics by': 'Who wrote the lyrics for [X]?',
#  'conferred by': 'Who confers the [X]?',
#  'anthem': 'What is the anthem of [X]?',
#  'parent astronomical body': 'What is the parent astronomical body of [X]?',
#  'list of works': 'What is the list of works associated with [X]?',
#  'pole position': 'Who secured the pole position in [X]?',
#  'regulates (molecular biology)': 'What does [X] regulate in molecular biology?',
#  'worshipped by': 'Who worships [X]?',
#  'editor': 'Who is the editor of [X]?',
#  'UTC date of spacecraft landing': 'What is the UTC date of spacecraft landing for [X]?',
#  'origin of the watercourse': 'What is the origin of the watercourse [X]?',
#  'exclave of': 'What is [X] an exclave of?',
#  'type of orbit': 'What type of orbit does [X] have?',
#  'oath made by': 'Who made an oath at [X]?',
#  'doctoral advisor': 'Who was the doctoral advisor of [X]?',
#  'interested in': 'What is [X] interested in?',
#  'crosses': 'What does [X] cross?',
#  'significant person': 'Who is a significant person related to [X]?',
#  'practiced by': 'What profession typically practiced by [X]?',
#  'film editor': 'Who is the film editor of [X]?',
#  'used by': 'Who uses [X]?',
#  'has immediate cause': 'What is the immediate cause of [X]?',
#  'set in period': 'What period is [X] set in?',
#  'wears': 'What does [X] typically wear?',
#  'director of photography': 'Who is the director of photography for [X]?',
#  'country of citizenship': 'What is the country of citizenship of [X]?',
#  'radio format': 'What is the radio format of [X]?',
#  'official residence': 'What is the official residence of [X]?',
#  'date of official opening': 'When was the official opening date of [X]?',
#  'commemorates': 'Who does [X] commemorate?',
#  'general manager': 'Who is the general manager of [X]?',
#  'publication date': 'When was the publication date of [X]?',
#  'present in work': 'In which work is the character [X] present?',
#  'studied by': 'What is [X] studied by?',
#  'stock market index': 'What is the stock market index of [X]?',
#  'bowling style': 'What is the bowling style of [X]?',
#  'film crew member': 'Who is a film crew member of [X]?',
#  'statistical leader': 'Who was the statistical leader in [X]?',
#  'taxonomic type': 'What is the taxonomic type of [X]?',
#  'successful candidate': 'Who was the successful candidate in the [X]?',
#  'exhibition history': 'Where has [X] been exhibited in its history?',
#  'takes place in fictional universe': 'In which fictional universe does [X] take place?',
#  'production company': 'Who was the production company for [X]?',
#  'standards body': 'What is the standards body for [X]?',
#  'mother': 'Who is the mother of [X]?',
#  'territory claimed by': 'Who claimed the territory of [X]?',
#  'honorific prefix': 'What is the honorific prefix of [X]?',
#  'country': 'What country is [X] associated with?',
#  'guidance system': 'What guidance system does [X] use?',
#  'time of discovery or invention': 'When was the time of discovery or invention for [X]?',
#  'commander of (DEPRECATED)': 'Who was the commander of [X]?',
#  'made from material': 'What material is [X] made from?',
#  'member of political party': 'What political party is [X] a member of?',
#  'member of': 'What organization is [X] a member of?',
#  'located on linear feature': 'What linear feature is [X] located on?',
#  'based on': 'What is [X] based on?',
#  'place of birth': 'Where was [X] born?',
#  'destination point': 'What is the destination point of [X]?',
#  'publisher': 'Who is the publisher of [X]?',
#  'noble title': 'What is the noble title of [X]?',
#  'language of work or name': 'What is the language of work or name of [X]?',
#  'language regulatory body': 'What is the language regulatory body of [X]?',
#  'executive producer': 'Who is the executive producer of [X]?',
#  'date of birth': 'What is the date of birth of [X]?',
#  'basic form of government': 'What is the basic form of government in [X]?',
#  'officeholder': 'Who is the officeholder of the position of [X]?',
#  'manner of death': 'What was the manner of death for [X]?',
#  'filming location': 'Where was [X] filmed?',
#  'appointed by': 'Who is [X] appointed by?',
#  'source of energy': 'What is the source of energy for [X]?',
#  'vehicle normally used': 'What vehicle is normally used by [X]?',
#  'father': 'Who is the father of [X]?',
#  'first flight': 'When was the first flight of [X]?',
#  'connecting service': 'What is the connecting service for [X]?',
#  'superhuman feature or ability': 'What is the superhuman feature or ability of [X]?',
#  'storyboard artist': 'Who is the storyboard artist for [X]?',
#  'parent club': 'Who is the parent club of [X]?',
#  'doctoral student': 'Who was the doctoral student of [X]?',
#  'victory': 'Which event did [X] achieve victory in?',
#  'health specialty': 'What health specialty is related to [X]?',
#  'military branch': 'What military branch was [X] a part of?',
#  'narrative location': 'Where is the narrative location of [X]?',
#  'political alignment': 'What is the political alignment of [X]?',
#  'this taxon is source of': 'What is [X] a source of?',
#  'producer': 'Who is the producer of [X]?',
#  'legislated by': 'Who legislated [X]?',
#  'board member': 'Who was a board member of [X]?',
#  'described by source': 'Which source described [X]?',
#  'hybrid of': 'What is [X] a hybrid of?',
#  'founded by': 'Who founded the [X]?',
#  'located in or next to body of water': 'Which body of water is [X] located in or next to?',
#  'named after': 'Who is [X] named after?',
#  'anatomical location': 'What is the anatomical location of [X]?',
#  'measured physical quantity': 'What is the measured physical quantity of [X]?',
#  'muscle origin': 'What is the muscle origin of [X]?',
#  'participant': 'Who was a participant in the [X]?',
#  'family': 'What family does [X] belong to?',
#  'given name': 'What is the given name of [X]?',
#  'measurement scale': 'What measurement scale is used for [X]?',
#  'home venue': 'Where is the home venue for [X]?',
#  'presenter': 'Who was the presenter of [X]?',
#  'lowest point': 'What is the lowest point in [X]?',
#  'office held by head of the organization': 'What is the office held by the head of the organization [X]?',
#  'gene substitution association with': 'What does the gene [X] have a substitution association with?',
#  'source of material': 'Where is the source of material for [X]?',
#  'cause of death': 'What was the cause of death for [X]?',
#  'member of sports team': 'What sports team is [X] a member of?',
#  'participant in': 'In which event did [X] participate?',
#  'inspired by': 'Who is [X] inspired by?',
#  'instance of': 'What is [X] an instance of?',
#  'means of locomotion': 'What is the means of locomotion for [X]?',
#  'medical examination': 'What kind of medical examination is used for [X]?',
#  'underlies': 'What does [X] underlie?',
#  'has seal, badge, or sigil': 'What is the seal, badge, or sigil of [X]?',
#  'lifestyle': 'What is the lifestyle of [X]?',
#  'has grammatical case': 'What grammatical case does [X] have?',
#  'structural engineer': 'Who is the structural engineer of [X]?',
#  'chief executive officer': 'Who was the chief executive officer of [X]?',
#  'debut participant': 'In which film did [X] make his debut appearance?',
#  'theme music': 'What is the theme music for [X]?',
#  'scheduled service destination': 'What is the scheduled service destination of [X]?',
#  'transport network': 'What kind of transport network is [X]?',
#  'located in time zone': 'What time zone is [X] located in?',
#  'original language of film or TV show': 'What is the original language of the film or TV show [X]?',
#  'manifestation of': 'What is [X] a manifestation of?',
#  'work period (end)': 'When did [X] cease operating?',
#  'maintained by': 'Who maintains [X]?',
#  'tributary': 'What is a tributary of [X]?',
#  'fabrication method': 'What is the fabrication method of [X]?',
#  'general classification of race participants': 'Who was a participant in the general classification of [X]?',
#  'programmed in': 'What is [X] programmed in?',
#  'diocese': 'What is the diocese of [X]?',
#  'structure replaces': 'What structure did [X] replace?',
#  'notation': 'What is the notation for [X]?',
#  'website account on': 'What website does [X] have an account on?',
#  'type locality (geology)': 'What is the type locality (geology) of [X]?',
#  'shares border with': 'Who does [X] share a border with?',
#  'head of government': 'Who is the head of government for [X]?',
#  'stated in': 'Where is [X] stated in?',
#  'signatory': 'Which country is a signatory of [X]?',
#  'primary destinations': 'What are the primary destinations of [X]?',
#  'top-level Internet domain': 'What is the top-level Internet domain of [X]?',
#  'points/goal scored by': 'Who scored points/goals in [X]?',
#  'sidekick of': 'Who is [X] the sidekick of?',
#  'replaces': 'What did [X] replace?',
#  'screenwriter': 'Who is the screenwriter of [X]?',
#  'tonality': 'What is the tonality of [X]?',
#  'Roman nomen gentilicium': 'What is the Roman nomen gentilicium of [X]?',
#  'armament': 'What is the armament of [X]?',
#  'UTC date of spacecraft launch': 'What was the UTC date of the spacecraft launch for [X]?',
#  'point in time': 'What point in time did [X] occur?',
#  'licensed to broadcast to': 'Where is [X] licensed to broadcast to?',
#  'subclass of': 'What is [X] a subclass of?',
#  'stepparent': 'Who is the stepparent of [X]?',
#  'author': 'Who is the author of [X]?',
#  'field of this occupation': 'What is the field of occupation for a [X]?',
#  'lake on watercourse': 'What sea does the lake on [X] lead to?',
#  'product certification': 'What product certification does [X] have?',
#  'crystal system': 'What crystal system does [X] belong to?',
#  'located on astronomical body': 'What astronomical body is [X] located on?',
#  'product or material produced or service provided': 'What product or material is produced by [X]?',
#  'discography': 'Who is the artist of the discography [X]?',
#  'activating neurotransmitter': 'What is the activating neurotransmitter of [X]?',
#  'parent organization': 'What is the parent organization of [X]?',
#  'interchange station': 'What is the interchange station for [X]?',
#  'innervates': 'What does the [X] innervate?',
#  'this zoological name is coordinate with': 'What is the zoological name [X] coordinate with?',
#  'employer': 'Who is the employer of [X]?',
#  'owner of': 'Who is the owner of [X]?',
#  'start point': 'Where did [X] start from?',
#  'exemplar of': 'What is [X] an exemplar of?'}

# %%
#  'production statistics': 'What is the main product in the production statistics of [X]?',
#  'backup or reserve team or crew': 'Who was a member of the backup or reserve team or crew for [X]?',
#  'edibility': 'Is [X] an edible mushroom?',
#  'Gram staining': 'What is the result of Gram staining for [X]?',
#  'substitute/deputy/replacement of office/officeholder': 'Who is the substitute/deputy/replacement officeholder of the [X]?',
#  'GUI toolkit or framework': 'What GUI toolkit or framework does [X] use?',
#  'symptoms and signs': 'What symptoms and signs does [X] show on muscles?',
#  'central bank/issuer': 'Who is the central bank/issuer of [X]?',
#  'has effect': 'What effect does [X] have on the Last Judgment?',
#  'follows': 'What does [X] follow in the geological time scale?',
#  'tracklist': 'Is "[X]" part of the tracklist for which song?',

import copy

relations_train_dict2 = copy.copy(relations_train_dict)

# %%
relations_train_dict2.pop('production statistics')
relations_train_dict2['backup or reserve team or crew'] = 'Who was a member of the backup team for [X]?'
relations_train_dict2['edibility'] = 'Is [X] edible?'
relations_train_dict2.pop('Gram staining')
relations_train_dict2['substitute/deputy/replacement of office/officeholder'] = 'Who is the substitute officeholder of the [X]?'
relations_train_dict2['has effect'] = 'What effect does [X] have?'
relations_train_dict2['follows'] = 'What does [X] follow?'
relations_train_dict2['tracklist'] = 'Whose tracklist is "[X]" a part of?'

# %%
len(relations_train_dict2)

import json
with open('relations2questions.json', 'w') as fp:
    json.dump(relations_train_dict2, fp)

# %%
len(relations_train_dict)
# Out:
# 546

# %%
relations_train_dict
# Out:
# {'surface played on': 'What kind of surface is [X] played on?',
#  'physically interacts with': 'What does [X] physically interact with?',
#  'designed by': 'Who was [X] designed by?',
#  'inception': 'When was the inception of [X]?'}

# %%
relations_train_dict_2
# Out:
# {'after a work by': ['after a work by',
#   'Who is the original author of the work [X] is based on?',
#   'Who is the author of the work that [X] is based on?',
#   7796,
#   8406],
#  'capital of': ['capital of',
#   'What is the capital of [X]?',
#   'What was [X] the capital of?',
#   645,
#   944],
#  'record held': ['record held',
#   'What record does [X] hold?',
#   'Who holds the record in [X]?',
#   27896,
#   126383]}

# %%
relations_train_dict_2
# Out:
# {'surface played on': ['surface played on',
#   'What kind of surface is the Jakarta Open played on?',
#   'What kind of surface is [X] played on?',
#   11103,
#   16363],
#  'after a work by': ['after a work by',
#   'What work by Tyler Perry was Diary of a Mad Black Woman based on?',
#   'What work by Herman Melville did Pola X come after?',
#   7796,
#   8406],
#  'physically interacts with': ['physically interacts with',
#   'What does nisoxetine physically interact with?',
#   'What does aripiprazole physically interact with?',
#   8484,
#   10712],
#  'designed by': ['designed by',
#   'Who designed the Cherry Street Strauss Trunnion Bascule Bridge?',
#   'Who designed [X]?',
#   7223,
#   8995],
#  'inception': ['inception',
#   'When was the [X] founded?',
#   'When was [X] founded?',
#   493,
#   1367],
#  'capital of': ['capital of',
#   'What is the capital of [X]?',
#   'What is the capital of the Belorussian SSR?',
#   645,
#   944],
#  'record held': ['record held',
#   'What record does [X] hold in?',
#   'Who holds the record in [X]?',
#   27896,
#   126383],
#  'team captain': ['team captain',
#   'Who is the team captain of [X]?',
#   'Who is the team captain of the Italian national team?',
#   899026,
#   1142931],
#  'main subject': ['main subject',
#   'What is the main subject of The Bandy Papers?',
#   'What is the main subject of [X]?',
#   2885,
#   3115],
#  'defendant': ['defendant',
#   'Who was the defendant in the 2005 child molestation trial?',
#   'Who was the defendant in [X]?',
#   940430,
#   1185160],
#  'voice actor': ['voice actor',
#   'Who is the voice actor for [X]?',
#   'Who is the voice actor of [X]?',
#   2365,
#   6434],
#  'torch lit by': ['torch lit by',
#   'Who lit the torch for the [X] Olympic Games?',
#   'Who lit the torch at [X]?',
#   586758,
#   624299],
#  'protocol': ['protocol',
#   'What protocol is the Linux kernel using?',
#   'What protocol is used by the Linux kernel for [X]?',
#   510582,
#   611810],
#  'applies to jurisdiction': ['applies to jurisdiction',
#   'What jurisdiction does [X] apply to?',
#   'What jurisdiction does EU Directive [X] apply to?',
#   1620,
#   1709],
#  'astronaut mission': ['astronaut mission',
#   "What was Valery Bykovsky's astronaut mission?",
#   'What astronaut mission did [X] participate in?',
#   2901,
#   7690]}

# %%
 dataset2["train"][int(relation_idxs[1])]
# Out:
# {'relation': 'P765',
#  'head': 'Internationaux de Strasbourg',
#  'tail': 'outdoor clay courts',
#  'title': '1995 Internationaux de Strasbourg',
#  'text': "The 1995 Internationaux de Strasbourg was a women's tennis tournament played on outdoor clay courts in Strasbourg in France that was part of Tier III of the 1995 WTA Tour. It was the ninth edition of the tournament and was held from May 22 through May 28, 1995."}

# %%
dataset2["train"][5]['head']
# Out:
# {'relation': 'P144',
#  'head': 'The Garden of Eden with the Fall of Man',
#  'tail': 'Genesis',
#  'title': 'The Garden of Eden with the Fall of Man',
#  'text': "The Garden of Eden with the Fall of Man or The Earthly Paradise with the Fall of Adam and Eve is a 1617 painting by Peter Paul Rubens (figures) and Jan Brueghel the Elder (flora and fauna). It is housed in the Mauritshuis, Netherlands. The painting depicts the moment just before the consumption of forbidden fruit and the fall of man. Adam and Eve are depicted beneath the tree of the knowledge of good and evil, where various fruits grow. On the opposite side the tree of life is depicted, also laden with fruits. The scene is a reference to Genesis 2:8–14. A monkey biting an apple to the left symbolizes sin. The sanguine monkey next to Adam is the hotspur who cannot resist temptation, while the choleric cat near Eve's heels represents cruel cunning. In Christian symbolism, several grapes in the foliage behind Adam and Eve represent Christ's death on the cross, as wine represents his blood."}

# %%
dataset2["train"][37]
# Out:
# {'relation': 'P22',
#  'head': 'Lord Ganesh',
#  'tail': 'Lord Shiva',
#  'title': 'Pandalam Mahadeva Temple',
#  'text': "Pandalam Mahadeva Temple is situated in between Thottakkonam and Mulampuzha villages of Pandalam in Kerala, India. Yearly Kettukazhcha festival is one of the attractions for tourists. 10 days major festival is celebrated for Lord Sivain 'Dhanu masa' November–December every year. the festival start by hosting traditional flag names 'kodiettu' and ends by 'aarattu'. the administration of this temple held by Mahadeva Seva Samithi participated by 12 villages '12 karakal'in Pandalam. It is believed that Lord Parasuram has installed the main idol of the Garbhagriha in this temple. Pandalam Mahadeva Temple is one of the oldest temples out of the 108 Shiva temples consecrated by the great 'Sanayasin Khara Muni'. The sacred and world famous temple is located on the left banks of the Achenkovil river, one side of this temple is in the banks of Achankovil river so this temple also known as 'Mukkal Vattom' 3 km away from Pandalam town in Kerala State. Pandalam is also world famous as the home town of Lord Ayyappan. The temple is unique with its natural procession route around the Sanctorum. The river flows touch the feet of Mahadeva Sanctorum, just like Ganges flows from Shiva's 'Jada' (hair). In addition to Lord Shiva the idols of Lord Ganesh (Ganapathy), 'Maya- Ekshi Amma', Lord Ayyappa, Nagaraja (Lord Snake), Lord Subramanian, Brahma Rakshas and Rakshas are also worshipped here. In effect the temple acts as the symbol and replica of 'KAILASAM'. Millions of devotees experienced the blessings from this holy place."}

# %%
# Out:
# (array([     37,      76,     797, ..., 1272967, 1273398, 1273508]),)

# %%
get_wikidata_property_label("P22")
# Out:
# 'father'

# %%
trex_test_relations = (set(dataset2["test"]['relation']))

# %%
len(trex_test_relations)
# Out:
# 34

# %%
len(list(trex_test_relations & trex_train_relations))
# Out:
# 0

# %%
import numpy as np
np.mean([relation[0]=="P" for relation in list(trex_train_relations)])
# Out:
# 0.7259552042160737

# %%
get_wikidata_property_label("P1264")
# Out:
# 'valid in period'

# %%
list(trex_train_relations)
# Out:
# ['P1411',
#  'P3461',
#  '[Holiday] is a national holiday of [Country]',
#  'P1304',
#  '[Play] is first performed on [Date]',
#  'P575',
#  'P2743',
#  'P1191',
#  'P282',
#  'P611',
#  'P730',
#  'P3701',
#  'P527',
#  'P176',
#  'P620',
#  '[Person] is the prime minister of [Country]',
#  '[Software] is used for [Purpose]',
#  'P669',
#  '[System] is a system in [Artifact]',
#  'P624',
#  'P1366',
#  'P1830',
#  'P1552',
#  '[Movie] is a spinoff of [Movie]',
#  'P1264',
#  '[Group] is founded by [Person]',
#  'P3403',
#  'P912',
#  'P3490',
#  'P1429',
#  'P3828',
#  '[Person] studies at [School]',
#  'P1302',
#  'P162',
#  '[Person] is born in [Location]',
#  'P2578',
#  'P3712',
#  'P237',
#  'P1057',
#  'P551',
#  '[Currency] is used in [Country]',
#  "[Sport Team]'s home field is [Location]",
#  'P410',
#  '[Museum] is memorial to [Event]',
#  'P123',
#  'P1923',
#  'P524',
#  '[Disease] has [Symptoms]',
#  '[River] drains [Location]',
#  'P16',
#  'P3438',
#  '[Artifact] is name of [Artifact]',
#  'P800',
#  '[Artifact] is used by [Person]',
#  'P2813',
#  'P1576',
#  'P1462',
#  'P1435',
#  'P30',
#  'P3092',
#  '[Person] plays in [Movie]',
#  'P788',
#  'P37',
#  'P1542',
#  'P2094',
#  '[Location] is exclave of [Country]',
#  'P131',
#  'P2695',
#  'P1445',
#  'P201',
#  'P186',
#  'P193',
#  '[Art Work] is sculpted by [Person]',
#  'P553',
#  '[Person] is born in [Country]',
#  'P609',
#  'P20',
#  'P2416',
#  '[Music] is made by [Artist]',
#  'P1038',
#  'P2579',
#  '[Food] is originated in [Country]',
#  'P1398',
#  'P2176',
#  'P559',
#  'P2670',
#  'P720',
#  'P463',
#  'P1619',
#  'P923',
#  '[Artifact] is used for its namesake of [Artifact]',
#  'P521',
#  'P689',
#  '[Head of Government] is appointed by [Head of Government]',
#  'P915',
#  'P1999',
#  'P1840',
#  'P2157',
#  'P479',
#  'P545',
#  'P2388',
#  'P169',
#  '[Person] is a student of [Person]',
#  'P197',
#  'P511',
#  '[Group] is founded at [Location]',
#  'P802',
#  'P1537',
#  '[Artifact] is a type of [Type]',
#  'P466',
#  'P930',
#  'P2098',
#  '[Building] is built from [Material]',
#  '[Person] causes [War]',
#  'P2155',
#  '[Person] is a candidate of [Election]',
#  'P1441',
#  'P417',
#  'P1716',
#  'P25',
#  'P2031',
#  '[River] is a tributary of [River]',
#  '[Location] is next to [Location]',
#  'P344',
#  'P425',
#  'P2597',
#  '[Group] is created on [Date]',
#  'P279',
#  'P31',
#  'P1035',
#  '[Location] is split from [Location]',
#  '[Art Work] is directed by [Person]',
#  'P264',
#  '[Person] is a cinematographer of [Movie]',
#  'P136',
#  '[City] is the capital of [Country]',
#  'P289',
#  'P840',
#  'P450',
#  'P868',
#  'P149',
#  '[Person] is the mayor of [City]',
#  'P517',
#  'P127',
#  'P150',
#  'P196',
#  'P681',
#  'P2632',
#  'P2286',
#  'P3320',
#  '[Artifact] is formation of [Army]',
#  '[Law] is enacted by [Group]',
#  'P1906',
#  'P543',
#  'P2522',
#  'P1372',
#  'P610',
#  '[Country] is in [Continent]',
#  '[Company] is in a sector of [Sector]',
#  'P556',
#  'P141',
#  'P729',
#  'P3342',
#  'P190',
#  'P2505',
#  'P85',
#  'P157',
#  'P1531',
#  '[Company] is a subsidiary of [Company]',
#  '[Aircraft] makes the maiden flight on [Date]',
#  'P569',
#  'P796',
#  'P166',
#  'P69',
#  'P823',
#  'P3091',
#  '[Person] is killed by [Person]',
#  'P407',
#  'P1308',
#  '[Bridge] crosses [Artifact]',
#  'P3833',
#  'P115',
#  'P2318',
#  '[Location] is an Indian reservation in [Country]',
#  'P3081',
#  'P750',
#  'P991',
#  'P3716',
#  'P1363',
#  'P841',
#  'P6',
#  'P826',
#  '[Group] is a predecessor of [Group]',
#  '[Person] dies at [Location]',
#  'P276',
#  'P248',
#  'P134',
#  "[Organization]'s ideology is [Ideology]",
#  '[Person] is the chair of [Group]',
#  'P2032',
#  'P1336',
#  'P1574',
#  'P2673',
#  'P945',
#  '[Person] is the monarch of [Country]',
#  'P1049',
#  'P414',
#  '[Movie] is [Genre]',
#  'P421',
#  'P3679',
#  'P2647',
#  'P108',
#  'P744',
#  'P942',
#  'P647',
#  'P2849',
#  '[City] is a twin city of [City]',
#  'P1382',
#  'P462',
#  'P26',
#  '[Event] is since [Date]',
#  'P403',
#  'P400',
#  '[Artifact] is formed from [Artifact]',
#  '[Group] is legislature of [Country]',
#  'P2389',
#  'P2978',
#  'P485',
#  'P1881',
#  'P361',
#  'P1376',
#  'P404',
#  'P1000',
#  'P2499',
#  '[Person] is [Rank]',
#  'P97',
#  '[Person] is [Occupation]',
#  'P1074',
#  '[City] is in [Country]',
#  'P1532',
#  'P135',
#  '[Group] has a section of [Group]',
#  'P66',
#  'P1875',
#  '[Sport Team] plays at [Competition]',
#  'P3373',
#  'P748',
#  'P2359',
#  'P746',
#  '[Pet] is a pet of [Person]',
#  'P398',
#  '[Culture] is originated in [Country]',
#  '[Company] operates [Vehicle]',
#  'P790',
#  'P1196',
#  'P943',
#  '[Person] has [Diseases]',
#  'P155',
#  'P927',
#  'P2012',
#  '[Company] owns [Product]',
#  '[Artists] leads [Movement]',
#  '[Competition] is a league of [Sport]',
#  'P35',
#  'P50',
#  'P1073',
#  'P500',
#  'P39',
#  'P3179',
#  'P2825',
#  'P1962',
#  '[Star] is a [Constellation]',
#  'P725',
#  'P2596',
#  'P156',
#  'P65',
#  '[Person] is a mistress of [Person]',
#  'P542',
#  '[Artifact] is built on [Date]',
#  'P928',
#  '[Group] is funded by [Person]',
#  '[Town] is in [Location]',
#  'P598',
#  'P103',
#  '[Person] plays in [Sport Team]',
#  'P1596',
#  '[Airline] is in [Airline Alliance]',
#  'P619',
#  'P664',
#  'P2936',
#  'P2515',
#  'P3448',
#  'P3173',
#  'P516',
#  'P530',
#  'P183',
#  'P1321',
#  'P2439',
#  'P58',
#  'P137',
#  'P2974',
#  'P2633',
#  'P172',
#  'P451',
#  'P92',
#  'P767',
#  'P803',
#  '[Language] is a dialect of [Language]',
#  'P533',
#  'P2341',
#  '[Person] is a consort of [Person]',
#  'P608',
#  'P105',
#  'P1419',
#  'P1427',
#  '[Movie] is first broadcast on [Date]',
#  'P128',
#  '[Country] is enclaved by [Country]',
#  'P87',
#  'P1416',
#  'P580',
#  '[Person] live in [Location]',
#  'P2079',
#  'P437',
#  'P1995',
#  'P469',
#  'P209',
#  'P3190',
#  '[Museum] is dedicated to [Person]',
#  'P1027',
#  'P1412',
#  'P780',
#  'P144',
#  'P924',
#  '[Chemical Material] is made from [Stone]',
#  'P625',
#  'P449',
#  'P1365',
#  '[Person] is a manager of [Sport Team]',
#  '[Job] is the head of state in [Location]',
#  '[Land] is [Country]',
#  'P263',
#  'P54',
#  '[Art Work] is published on [Date]',
#  'P184',
#  '[Play] is performed by [Person]',
#  'P1877',
#  'P461',
#  'P1158',
#  'P2184',
#  'P88',
#  'P747',
#  '[Academic Subject] studies [Topic]',
#  'P1064',
#  'P1433',
#  'P121',
#  'P1924',
#  'P1605',
#  'P582',
#  '[Medicine] is for [Disease]',
#  '[Person] is drafted by [Group]',
#  '[Art Work] is published in [Magazine]',
#  'P514',
#  'P118',
#  'P413',
#  'P822',
#  '[Person] is a chancellor of [Country]',
#  '[Person] choreographs [Play]',
#  'P567',
#  'P734',
#  'P1072',
#  'P3085',
#  '[Group] is a religious order of [Group]',
#  '[God] is the god of [Religion]',
#  'P22',
#  '[Disease] is caused by [Virus]',
#  '[Artifact] is named after [Person]',
#  'P789',
#  'P195',
#  'P457',
#  'P828',
#  'P2291',
#  'P1066',
#  'P1478',
#  'P1809',
#  'P642',
#  'P1327',
#  'P2789',
#  '[Person] works at [Group]',
#  'P177',
#  'P1346',
#  'P40',
#  "[Country]'s county seat is [Location]",
#  'P189',
#  'P505',
#  'P921',
#  'P84',
#  'P682',
#  'P206',
#  'P1028',
#  'P1136',
#  'P3018',
#  'P1387',
#  'P1056',
#  'P1990',
#  'P2962',
#  '[Museum] has [Collection of Work]',
#  'P1389',
#  'P194',
#  'P710',
#  '[Person] belongs to [Record Label]',
#  'P1454',
#  '[Artifact] is a patron saint of [Country]',
#  '[Food] is made from [Ingredient]',
#  'P2321',
#  'P3113',
#  '[Event] happens on [Date]',
#  'P941',
#  '[Person] is a concubine of [Person]',
#  'P119',
#  'P287',
#  '[Medication] is for [Disease]',
#  'P163',
#  'P606',
#  'P523',
#  '[Artifact] is maintained by [Company]',
#  'P1313',
#  'P427',
#  'P1414',
#  'P736',
#  'P38',
#  'P740',
#  'P1002',
#  'P179',
#  'P3095',
#  'P1001',
#  '[Person] is buried at [Tomb]',
#  'P1037',
#  'P674',
#  '[River] outflows to [Location]',
#  'P688',
#  '[Street] is in the street of [Location]',
#  'P2554',
#  'P2378',
#  'P208',
#  'P2828',
#  'P831',
#  'P275',
#  '[Person] is played at [Group]',
#  'P1876',
#  '[Fictional Character] is from [Art Work] ',
#  'P1408',
#  'P1142',
#  '[Award] is presented by [Company]',
#  '[Person] is the president of [Country]',
#  '[Software] is written in [Programming Language]',
#  'P726',
#  'P1889',
#  'P19',
#  '[Sport Team] wins [Competition]',
#  '[Person] and [Person] are married',
#  '[Person] is from [Era]',
#  '[Cathedral] is in [City]',
#  'P1068',
#  'P2238',
#  'P1589',
#  'P2868',
#  '[Person] plays [Fictional Character]',
#  'P522',
#  'P483',
#  'P2925',
#  'P577',
#  '[Artifact] is listed in [List]',
#  'P3015',
#  'P1029',
#  'P3103',
#  '[Location] is an administrative center of [Location]',
#  'P408',
#  '[Person] disappears on [Date]',
#  'P2746',
#  'P159',
#  'P113',
#  '[Army] has [Fleet]',
#  'P636',
#  'P366',
#  '[Company] has the headquarter in [Location]',
#  'P2551',
#  '[Group] is the parliament of [Country]',
#  'P411',
#  'P112',
#  'P655',
#  '[Government] is the jurisdiction of [City]',
#  'P3512',
#  'P807',
#  '[Artifact] is the platform of [Game]',
#  'P937',
#  '[Artifact] is discovered by [Person]',
#  'P676',
#  'P621',
#  'P1046',
#  'P2438',
#  'P3080',
#  'P47',
#  'P509',
#  'P1018',
#  'P1916',
#  'P735',
#  'P1672',
#  'P1192',
#  'P881',
#  'P2152',
#  '[Person] is a premier of [Group]',
#  '[Era] comes before [Era]',
#  'P98',
#  'P306',
#  'P114',
#  '[Person] is a commander of [Army]',
#  '[Person] studies [Academic Subject]',
#  'P59',
#  '[Person] is a patron of [Person]',
#  'P358',
#  '[Artifact] is influenced by [Artifact]',
#  '[Location] is on the coast of [Ocean]',
#  'P199',
#  'P111',
#  '[Software] is under license of [License]',
#  '[Group] is founded on [Date]',
#  'P167',
#  'P795',
#  "[PC]'s cpu is [CPU]",
#  '[Weapon] is used by [Person]',
#  'P631',
#  'P2358',
#  'P1202',
#  'P291',
#  'P520',
#  'P3450',
#  'P2546',
#  'P171',
#  'P2563',
#  'P2922',
#  'P277',
#  'P2674',
#  '[Person] is in [Prison]',
#  '[Music Artist] is [Genre]',
#  'P375',
#  "[Country]'s flag is [Artifact]",
#  'P703',
#  'P1344',
#  '[Bank] is the central bank of [Country]',
#  'P1071',
#  'P547',
#  '[Person] first finds [Disease]',
#  'P138',
#  'P86',
#  'P27',
#  '[Country] is [Political Party] assembly',
#  'P1434',
#  'P1885',
#  "[Material]'s crystal system is [Crystal System]",
#  '[Bridge] crosses [River]',
#  'P1269',
#  '[Island] is [Country]',
#  '[Company] publishes [Art Work]',
#  'P1535',
#  'P2545',
#  'P512',
#  'P397',
#  'P585',
#  'P974',
#  '[Religion] is a denomination by [Artifact]',
#  '[Person] dies on [Date]',
#  'P2512',
#  'P272',
#  '[Army] is based in [Location]',
#  '[Game] is produced by [Company]',
#  'P2700',
#  '[Person] coins [Artifact]',
#  'P751',
#  '[Location] is the highest peak in [Country]',
#  'P61',
#  'P452',
#  'P418',
#  '[Language] consists of [Alphabet]',
#  'P3301',
#  'P1383',
#  'P1455',
#  'P488',
#  'P706',
#  'P364',
#  '[Person] is a coach of [Sport Team]',
#  '[Person] built [Artifact]',
#  'P412',
#  'P200',
#  'P576',
#  '[Movie] is produced by [Company]',
#  'P618',
#  '[Country] joins [War]',
#  'P571',
#  '[Movie] is in the universe of [Art Work]',
#  'P205',
#  'P880',
#  '[Event] ends on [Date]',
#  '[Sport Team] is an affiliate of [Sport Team]',
#  'P81',
#  'P3300',
#  'P360',
#  'P1636',
#  '[Art Work] is adapted from [Art Work]',
#  '[Art Work] is painted by [Person]',
#  'P2989',
#  '[Person] is active in [Location]',
#  'P495',
#  'P185',
#  'P376',
#  'P568',
#  'P3275',
#  '[Person] is the emperor of [Country]',
#  'P931',
#  '[Event] takes place at [Location]',
#  '[Movie] is a libretto by [Person]',
#  'P2175',
#  'P770',
#  'P126',
#  'P641',
#  'P708',
#  '[Artifact] has [Engine]',
#  'P1951',
#  'P3137',
#  'P562',
#  'P2959',
#  'P1312',
#  'P612',
#  'P832',
#  '[Person] is a husband of [Person]',
#  '[Location] is closed on [Date]',
#  'P518',
#  'P532',
#  '[Person] has a house in [Location]',
#  'P2500',
#  '[Art Work] is a painting of [Person]',
#  'P371',
#  'P36',
#  'P859',
#  'P541',
#  '[Art Work] follows after [Art Work]',
#  '[Person] is a member of [Music Group]',
#  'P2650',
#  'P286',
#  'P1479',
#  'P3174',
#  '[Person] is convicted of [Crime]',
#  "[Group]'s leader is [Person]",
#  'P1299',
#  'P2541',
#  'P467',
#  'P1598',
#  '[Art Work] is written by [Person]',
#  'P210',
#  'P607',
#  'P797',
#  'P1080',
#  'P2408',
#  'P122',
#  'P1557',
#  '[Building] has an architectural style of [Person]',
#  '[Planet] is in the orbit of [Orbit]',
#  'P570',
#  '[Planet] is a satellite of [Planet]',
#  'P129',
#  '[Person] is awarded by [Award]',
#  'P180',
#  '[Person] is born on [Date]',
#  'P1444',
#  'P1420',
#  'P102',
#  'P501',
#  'P241',
#  'P825',
#  'P415',
#  'P1591',
#  'P1040',
#  'P812',
#  '[Person] is [Sex]',
#  '[Railway] is in [Location]',
#  'P57',
#  '[Music] is released on [Date]',
#  'P793',
#  'P1639',
#  'P1268',
#  'P3764',
#  '[Person] is the queen of [Country] ',
#  '[Location] is in [Planet]',
#  '[Fictional Character] is a mascot of [Sport Team]',
#  'P3349',
#  'P1431',
#  'P1880',
#  'P110',
#  '[Person] creates [Work]',
#  '[Location] is the lowest point of [Location]',
#  'P170',
#  '[Plant] is [Type]',
#  '[State] is a state of [Country]',
#  '[Government] is the government of [Country]',
#  'P2283',
#  'P78',
#  '[Council] is the council of [Country]',
#  'P739',
#  '[Sport Team] plays in [Competition]',
#  'P1547',
#  'P1290',
#  'P91',
#  '[Location] is a sovereign state of [Location]',
#  'P504',
#  '[Art Work] is a translation of [Art Work]',
#  'P1654',
#  'P550',
#  'P737',
#  'P765',
#  'P21',
#  'P1731',
#  'P1891',
#  'P178',
#  'P1399',
#  'P3033',
#  '[Artifact] is a version of [Artifact]',
#  'P1595',
#  'P161',
#  'P2575',
#  '[Country] has [History]',
#  'P749',
#  'P634',
#  'P658',
#  'P2348',
#  '[Person] is the leader of [Dynasty]',
#  'P1343',
#  'P1303',
#  'P885',
#  'P1050',
#  '[Person] is a presenter of [TV show]',
#  'P833',
#  'P106',
#  'P175',
#  'P355',
#  'P53',
#  '[Person] is the head of government of [Country]',
#  'P1079',
#  'P3279',
#  'P3161',
#  'P101',
#  'P140',
#  '[Artifact] is the OS of [Software]',
#  'P913',
#  '[Fruit] is [Type]',
#  'P870',
#  'P17',
#  'P629',
#  'P1582',
#  'P460']

# %%
get_wikidata_property_label
